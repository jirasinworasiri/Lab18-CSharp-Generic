// %% [markdown]
// # Lab 18 Exercise 4

// %% [markdown]
// ## Generic method

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab18_Ex04
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// // Generic method
// Generic.Print(10);
// Generic.Print("Hello World");
// Generic.Print(12345.678);
//
//
// public static class Generic
// {
//     public static void Print <T> (T value)
//     {
//         System.Console.WriteLine(value);
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab18_Ex04
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab18_Ex04
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// สามารถส่งค่า Primitive Type (int, double) และ Reference Type (string) ได้
//
// มีความยืดหยุ่นสูง โดยไม่ต้อง Overload เมทอดหลายตัว
